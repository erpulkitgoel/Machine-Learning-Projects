# %%
import pandas as pd
import sqlite3

# %%
connection =sqlite3.connect('./Data/Amazon_food_review/database.sqlite')
data = pd.read_sql_query("SELECT * FROM Reviews", connection)
data.head(5)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
data_score_notThree = pd.read_sql_query("Select * from Reviews where Score != 3",connection)

# %%
data_score_notThree.head(5)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
data_score_notThree.shape
# Out:
# (525814, 10)

# %%
data_summary1 = pd.read_sql_query("select * from reviews where Score= 1",connection)
data_summary1.shape
# Out:
# (52268, 10)

# %%
data_summary2 = pd.read_sql_query("select * from reviews where Score= 2",connection)
print(data_summary2.shape)
data_summary3 = pd.read_sql_query("select * from reviews where Score= 3",connection)
print(data_summary3.shape)
data_summary4 = pd.read_sql_query("select * from reviews where Score= 4",connection)
print(data_summary4.shape)
data_summary5 = pd.read_sql_query("select * from reviews where Score= 5",connection)
print(data_summary5.shape)
data_summary6 = pd.read_sql_query("select * from reviews where Score= 6",connection)
print(data_summary6.shape)
data_summary7 = pd.read_sql_query("select * from reviews where Score= 7",connection)
print(data_summary7.shape)
# Out:
# (29769, 10)
# (42640, 10)
# (80655, 10)
# (363122, 10)
# (0, 10)
# (0, 10)

# %%
data_dist_profileName = pd.read_sql_query("Select distinct ProfileName from Reviews", connection)
print(data_dist_profileName.shape)
data_dist_profileName.head(10)
# Out:
# (218418, 1)
#                        ProfileName
# 0                       delmartian
# 1                           dll pa
# 2  Natalia Corres "Natalia Corres"
# 3                             Karl
# 4    Michael D. Bigham "M. Wassir"
# 5                   Twoapennything
# 6                David C. Sullivan
# 7               Pamela G. Williams
# 8                         R. James
# 9                    Carol A. Reed

# %%
data_orderBy  = pd.read_sql_query("select * from Reviews where Score =5 Order by Time ASC",connection)
data_orderBy.head(10)
# Out:
#        Id   ProductId          UserId               ProfileName  \
# 0  150524  0006641040   ACITT7DI6IDDL           shari zychinski
# 1  150501  0006641040   AJ46FKXOVC7NR        Nicholas A Mesiano
# 2  451856  B00004CXX9   AIUWLEQ1ADEG5          Elizabeth Medina
# 3  230285  B00004RYGX  A344SMIA5JECGM           Vincent P. Ross
# 4  374359  B00004CI84  A344SMIA5JECGM           Vincent P. Ross
# 5  451878  B00004CXX9  A344SMIA5JECGM           Vincent P. Ross
# 6  451855  B00004CXX9   AJH6LUC1UT1ON  The Phantom of the Opera
# 7  230348  B00004RYGX  A1048CYU0OV4O8              Judy L. Eans
# 8  374422  B00004CI84  A1048CYU0OV4O8              Judy L. Eans
# 9  451949  B00004CXX9  A1048CYU0OV4O8              Judy L. Eans
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score       Time  \
# 0                     0                       0      5  939340800
# 1                     2                       2      5  940809600
# 2                     0                       0      5  944092800
# 3                     1                       2      5  944438400
# 4                     1                       2      5  944438400
# 5                     1                       2      5  944438400
# 6                     0                       0      5  946857600
# 7                     2                       2      5  947376000
# 8                     2                       2      5  947376000
# 9                     2                       2      5  947376000
#
#                                              Summary  \
# 0                          EVERY book is educational
# 1  This whole series is great way to spend time w...
# 2                               Entertainingl Funny!
# 3                            A modern day fairy tale
# 4                            A modern day fairy tale
# 5                            A modern day fairy tale
# 6                                         FANTASTIC!
# 7                                              GREAT
# 8                                              GREAT
# 9                                              GREAT
#
#                                                 Text
# 0  this witty little book makes my son laugh at l...
# 1  I can remember seeing the show when it aired o...
# 2  Beetlejuice is a well written movie ..... ever...
# 3  A twist of rumplestiskin captured on film, sta...
# 4  A twist of rumplestiskin captured on film, sta...
# 5  A twist of rumplestiskin captured on film, sta...
# 6  Beetlejuice is an excellent and funny movie. K...
# 7  THIS IS ONE MOVIE THAT SHOULD BE IN YOUR MOVIE...
# 8  THIS IS ONE MOVIE THAT SHOULD BE IN YOUR MOVIE...
# 9  THIS IS ONE MOVIE THAT SHOULD BE IN YOUR MOVIE...

# %%
data_groupBy = pd.read_sql_query("Select Score, Count(*) from Reviews Group by Score", connection)
data_groupBy.head(10)
# Out:
#    Score  Count(*)
# 0      1     52268
# 1      2     29769
# 2      3     42640
# 3      4     80655
# 4      5    363122

# %%
data_groupBy2 = pd.read_sql_query("select ProfileName, AVG(Score) from Reviews group by ProfileName", connection)
data_groupBy2.head(10)
# Out:
#                                    ProfileName  AVG(Score)
# 0                                                    3.0
# 1                                                  5.0
# 2                                                5.0
# 3                                :Jury Duty:         4.0
# 4            ! MR. KNOW IT ALL  ;-b "DR SHOCK"         3.0
# 5  ! Metamorpho ;) "Reflective and Wiser Seer"         5.0
# 6                                          !!!         3.0
# 7                            !AmY!K! "!AmY!K!"         5.0
# 8                                    !Mamamia!         2.0
# 9                               "Bondo" "Paul"         5.0

# %%
data_groupBy3 = pd.read_sql_query("Select ProfileName, AVG(Score) from Reviews where ProfileName = 'Elizabeth Medina' Group by ProfileName", connection)

# %%
data_groupBy3.head(10)
# Out:
#         ProfileName  AVG(Score)
# 0  Elizabeth Medina         5.0

# %%
data_having = pd.read_sql_query("select ProfileName, AVG(Score) from Reviews group By ProfileName having AVG(Score) > 3", connection)
data_having.head(20)
# Out:
#                                     ProfileName  AVG(Score)
# 0                                                   5.0
# 1                                                 5.0
# 2                                 :Jury Duty:         4.0
# 3   ! Metamorpho ;) "Reflective and Wiser Seer"         5.0
# 4                             !AmY!K! "!AmY!K!"         5.0
# 5                                "Bondo" "Paul"         5.0
# 6                         "Let them read books"         5.0
# 7                                   "all4gizmo"         5.0
# 8                              "aussiebeermatt"         4.0
# 9                                      "boycat"         5.0
# 10                                  "brandi756"         5.0
# 11                                  "bungfritz"         5.0
# 12                                   "dmab6395"         5.0
# 13                                     "finnao"         5.0
# 14                                    "gibraud"         5.0
# 15                    "insolent_shoeshine_grrl"         5.0
# 16                                   "kgremill"         5.0
# 17                                    "lenbone"         5.0
# 18                                  "lisah_007"         5.0
# 19                       "louandchrisbooksplus"         5.0

# %%
data_And = pd.read_sql_query("select * from Reviews where Score > 3 AND Score < 5", connection)
data_And.head(20)
# Out:
#      Id   ProductId          UserId  \
# 0     3  B000LQOCH0   ABXLMWJIXXAIN
# 1     6  B006K2ZZ7K   ADT0SRK1MGOEU
# 2    14  B001GVISJM  A18ECVX2RJ7HUE
# 3    28  B001GVISJM   AAAS38B98HMIK
# 4    33  B001EO5QW8   AOVROBZ8BNTP7
# 5    34  B001EO5QW8  A3PMM0NFVEJGK9
# 6    36  B001EO5QW8  A2CI0RLADCRKPF
# 7    39  B001EO5QW8  A2GHZ2UTV2B0CD
# 8    49  B001EO5QW8   ALOR97KTZTK1P
# 9    53  B000G6RPMY   A9L6L5H9BPEBO
# 10   55  B002GWHC0G  A1ND7WC5LXOU48
# 11   82  B0066DMI6Y   AZLONLC8OZPEC
# 12  102  B004K2IHUO  A3D1TXE98KRKYO
# 13  103  B004K2IHUO   AVCA516CFZ9HF
# 14  128  B003OB0IB8   A34UG2TNXIL0Y
# 15  136  B003OB0IB8  A2BZNXMV0LC7OE
# 16  141  B001GVISJW   ARS5Q7LR6HWPG
# 17  142  B001GVISJW  A2YIO225BTKVPU
# 18  153  B005P0HHGK   AISCBGJRPPZ5G
# 19  163  B000ITVLE2   A6Y8N2GHDH0ZO
#
#                                          ProfileName  HelpfulnessNumerator  \
# 0                    Natalia Corres "Natalia Corres"                     1
# 1                                     Twoapennything                     0
# 2                                    willie "roadie"                     2
# 3                                       Heather Dube                     0
# 4                                          S. Potter                    19
# 5                           Megan "Bad at Nicknames"                    13
# 6                                         T. J. Ryan                     3
# 7                                        JERRY REITH                     0
# 8                                       knitty pants                     1
# 9                                    Edwin C. Pauzer                     1
# 10                          David Belton "Proteus 1"                     2
# 11                                    John W. Hollis                     1
# 12                               Danny "The Student"                     2
# 13                                         S. Fowler                     0
# 14                                         Austin H.                     4
# 15                                            Alanna                     0
# 16                                   N. Pine "pcone"                     0
# 17  Angel_Boy "Treat the people around you the wa...                     0
# 18                                KT "loves to read"                     0
# 19                                             Matty                     0
#
#     HelpfulnessDenominator  Score        Time  \
# 0                        1      4  1219017600
# 1                        0      4  1342051200
# 2                        2      4  1288915200
# 3                        1      4  1331856000
# 4                       19      4  1163376000
# 5                       13      4  1166313600
# 6                        3      4  1210464000
# 7                        0      4  1350777600
# 8                        2      4  1191715200
# 9                        1      4  1348876800
# 10                       2      4  1322438400
# 11                       1      4  1324598400
# 12                       3      4  1256515200
# 13                       0      4  1335139200
# 14                       4      4  1325808000
# 15                       0      4  1333756800
# 16                       0      4  1314489600
# 17                       0      4  1301788800
# 18                       0      4  1326585600
# 19                       0      4  1348272000
#
#                                               Summary  \
# 0                               "Delight" says it all
# 1                                          Nice Taffy
# 2                                   fresh and greasy!
# 3                         Great Bargain for the Price
# 4                        Best of the Instant Oatmeals
# 5                                        Good Instant
# 6                                          satisfying
# 7                       GOOD WAY TO START THE DAY....
# 8   Very good but next time I won't order the Vari...
# 9            You'll go nuts over Ass-Kickin' Peanuts.
# 10                            Roasts up a smooth brew
# 11                                              Great
# 12                                      Great Support
# 13                                              TART!
# 14    Tastes great. Love Hot & Spicy. Bad price here.
# 15              Tastes great, but is cheaper locally.
# 16                                         Nice snack
# 17                                      Good Licorice
# 18                                        tastes good
# 19                                            Not Bad
#
#                                                  Text
# 0   This is a confection that has been around a fe...
# 1   I got a wild hair for taffy and ordered this f...
# 2   good flavor! these came securely packed... the...
# 3   I was so glad Amazon carried these batteries. ...
# 4   McCann's Instant Oatmeal is great if you must ...
# 5   This is a good instant oatmeal from the best o...
# 6   McCann's Instant Irish Oatmeal, Variety Pack o...
# 7   I WAS VISITING MY FRIEND NATE THE OTHER MORNIN...
# 8   I really like the Maple and Brown Sugar flavor...
# 9   This wasn't in stock the last time I looked. I...
# 10  I roast at home with a stove-top popcorn poppe...
# 11  Great gift for all ages! I purchased these gia...
# 12  Arrived slightly thawed. My parents wouldn't a...
# 13  The crust on these tarts are perfect.  My husb...
# 14  I've been a fan of Hot & Spicy Maruchan Ramen ...
# 15  I love this flavor of ramen! I don't eat other...
# 16  I bought this for our office to give people so...
# 17  Twizzlers brand licorice is much better than t...
# 18  Got this for my brother who is on Jorge Cruise...
# 19  I'm not familiar with the Safcol brand but bei...

# %%
data_OR = pd.read_sql_query("Select * from Reviews where Score = 2 Or Score =4", connection)
data_OR.head(10)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 1   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 2   6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
# 3  14  B001GVISJM  A18ECVX2RJ7HUE                  willie "roadie"
# 4  17  B001GVISJM  A3KLWF6WQ5BNYO                   Erica Neathery
# 5  28  B001GVISJM   AAAS38B98HMIK                     Heather Dube
# 6  33  B001EO5QW8   AOVROBZ8BNTP7                        S. Potter
# 7  34  B001EO5QW8  A3PMM0NFVEJGK9         Megan "Bad at Nicknames"
# 8  36  B001EO5QW8  A2CI0RLADCRKPF                       T. J. Ryan
# 9  39  B001EO5QW8  A2GHZ2UTV2B0CD                      JERRY REITH
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      4  1219017600
# 1                     3                       3      2  1307923200
# 2                     0                       0      4  1342051200
# 3                     2                       2      4  1288915200
# 4                     0                       0      2  1348099200
# 5                     0                       1      4  1331856000
# 6                    19                      19      4  1163376000
# 7                    13                      13      4  1166313600
# 8                     3                       3      4  1210464000
# 9                     0                       0      4  1350777600
#
#                          Summary  \
# 0          "Delight" says it all
# 1                 Cough Medicine
# 2                     Nice Taffy
# 3              fresh and greasy!
# 4                     poor taste
# 5    Great Bargain for the Price
# 6   Best of the Instant Oatmeals
# 7                   Good Instant
# 8                     satisfying
# 9  GOOD WAY TO START THE DAY....
#
#                                                 Text
# 0  This is a confection that has been around a fe...
# 1  If you are looking for the secret ingredient i...
# 2  I got a wild hair for taffy and ordered this f...
# 3  good flavor! these came securely packed... the...
# 4  I love eating them and they are good for watch...
# 5  I was so glad Amazon carried these batteries. ...
# 6  McCann's Instant Oatmeal is great if you must ...
# 7  This is a good instant oatmeal from the best o...
# 8  McCann's Instant Irish Oatmeal, Variety Pack o...
# 9  I WAS VISITING MY FRIEND NATE THE OTHER MORNIN...

# %%
data_And_OR = pd.read_sql_query("Select * from Reviews where Score > 1 And Score < 4 OR Score =5", connection)
data_And_OR.head(10)
# Out:
#    Id   ProductId          UserId                    ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                     delmartian
# 1   4  B000UA0QIQ  A395BORC6FGVXV                           Karl
# 2   5  B006K2ZZ7K  A1UQRSCLF8GW1T  Michael D. Bigham "M. Wassir"
# 3   7  B006K2ZZ7K  A1SP2KVKFXXRU1              David C. Sullivan
# 4   8  B006K2ZZ7K  A3JRGQVEQN31IQ             Pamela G. Williams
# 5   9  B000E7L2R4  A1MZYO9TZK0BBI                       R. James
# 6  10  B00171APVA  A21BT40VZCCYT4                  Carol A. Reed
# 7  11  B0001PB9FE  A3HDKO7OW0QNK4                   Canadian Fan
# 8  12  B0009XLVG0  A2725IB4YY9JEB         A Poeng "SparkyGoHome"
# 9  15  B001GVISJM  A2MUGFV2TDQ47K            Lynrie "Oh HELL no"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     3                       3      2  1307923200
# 2                     0                       0      5  1350777600
# 3                     0                       0      5  1340150400
# 4                     0                       0      5  1336003200
# 5                     1                       1      5  1322006400
# 6                     0                       0      5  1351209600
# 7                     1                       1      5  1107820800
# 8                     4                       4      5  1282867200
# 9                     4                       5      5  1268352000
#
#                                              Summary  \
# 0                              Good Quality Dog Food
# 1                                     Cough Medicine
# 2                                        Great taffy
# 3      Great!  Just as good as the expensive brands!
# 4                             Wonderful, tasty taffy
# 5                                         Yay Barley
# 6                                   Healthy Dog Food
# 7                    The Best Hot Sauce in the World
# 8  My cats LOVE this "diet" food better than thei...
# 9                       Strawberry Twizzlers - Yummy
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  If you are looking for the secret ingredient i...
# 2  Great taffy at a great price.  There was a wid...
# 3  This saltwater taffy had great flavors and was...
# 4  This taffy is so good.  It is very soft and ch...
# 5  Right now I'm mostly just sprouting this so my...
# 6  This is a very healthy dog food. Good for thei...
# 7  I don't know if it's the cactus or the tequila...
# 8  One of my boys needed to lose some weight and ...
# 9  The Strawberry Twizzlers are my guilty pleasur...

# %%
data_Like = pd.read_sql_query("Select ProfileName, Score from Reviews where ProfileName Like 'A%' ", connection)
data_Like.head(10)
# Out:
#                 ProfileName  Score
# 0    A Poeng "SparkyGoHome"      5
# 1  Abby Chase "gluten free"      5
# 2    amateur amazon shopper      5
# 3                     Ash52      5
# 4          Amazon-tron 3000      5
# 5             Adam E. Smith      5
# 6                      Aldo      5
# 7                     Alfbo      5
# 8             Anne Kirkwood      5
# 9                 Austin H.      4

# %%
data_Like2 = pd.read_sql_query("Select ProfileName, AVG(Score) from Reviews where ProfileName Like 'A%' group by ProfileName", connection)
data_Like2.head(10)
# Out:
#               ProfileName  AVG(Score)
# 0                       A    3.369231
# 1         A  Web "A  Web"    4.500000
# 2                A  buyer    3.000000
# 3                   A "A"    5.000000
# 4             A "CA Girl"    1.000000
# 5           A "beachgirl"    5.000000
# 6  A 10-year old customer    5.000000
# 7                A Arnold    5.000000
# 8                     A B    2.000000
# 9          A Baker Person    5.000000

# %%
data_Like3  = pd.read_sql_query("Select Summary, Score from Reviews where Summary Like 'Good%' ", connection)
data_Like3.head(10)
# Out:
#                          Summary  Score
# 0          Good Quality Dog Food      5
# 1                   Good Instant      4
# 2  GOOD WAY TO START THE DAY....      4
# 3             Good Hot Breakfast      5
# 4                           good      5
# 5                           Good      5
# 6          Good healthy dog food      5
# 7            Good for Feline UTI      5
# 8                  Good Licorice      4
# 9           Good anytime hot tea      5

# %%
data_IN = pd.read_sql_query("Select * from Reviews where Score IN (1,5)", connection)
data_IN.head(10)
# Out:
#    Id   ProductId          UserId                    ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                     delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                         dll pa
# 2   5  B006K2ZZ7K  A1UQRSCLF8GW1T  Michael D. Bigham "M. Wassir"
# 3   7  B006K2ZZ7K  A1SP2KVKFXXRU1              David C. Sullivan
# 4   8  B006K2ZZ7K  A3JRGQVEQN31IQ             Pamela G. Williams
# 5   9  B000E7L2R4  A1MZYO9TZK0BBI                       R. James
# 6  10  B00171APVA  A21BT40VZCCYT4                  Carol A. Reed
# 7  11  B0001PB9FE  A3HDKO7OW0QNK4                   Canadian Fan
# 8  12  B0009XLVG0  A2725IB4YY9JEB         A Poeng "SparkyGoHome"
# 9  13  B0009XLVG0   A327PCT23YH90                             LT
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     0                       0      5  1350777600
# 3                     0                       0      5  1340150400
# 4                     0                       0      5  1336003200
# 5                     1                       1      5  1322006400
# 6                     0                       0      5  1351209600
# 7                     1                       1      5  1107820800
# 8                     4                       4      5  1282867200
# 9                     1                       1      1  1339545600
#
#                                              Summary  \
# 0                              Good Quality Dog Food
# 1                                  Not as Advertised
# 2                                        Great taffy
# 3      Great!  Just as good as the expensive brands!
# 4                             Wonderful, tasty taffy
# 5                                         Yay Barley
# 6                                   Healthy Dog Food
# 7                    The Best Hot Sauce in the World
# 8  My cats LOVE this "diet" food better than thei...
# 9               My Cats Are Not Fans of the New Food
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  Great taffy at a great price.  There was a wid...
# 3  This saltwater taffy had great flavors and was...
# 4  This taffy is so good.  It is very soft and ch...
# 5  Right now I'm mostly just sprouting this so my...
# 6  This is a very healthy dog food. Good for thei...
# 7  I don't know if it's the cactus or the tequila...
# 8  One of my boys needed to lose some weight and ...
# 9  My cats have been happily eating Felidae Plati...

# %%
data_ISNULL = pd.read_sql_query("Select * from Reviews where Score IS NULL ", connection)
data_ISNULL.head(10)
# Out:
# Empty DataFrame
# Columns: [Id, ProductId, UserId, ProfileName, HelpfulnessNumerator, HelpfulnessDenominator, Score, Time, Summary, Text]
# Index: []

# %%
data_ISNOTNULL = pd.read_sql_query("Select * from Reviews where Score IS NOT NULL", connection)
data_ISNOTNULL.head(5)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
data_Between = pd.read_sql_query("Select * from Reviews where Score Between 2 AND 4", connection)
data_Between.head(7)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 1   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 2   6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
# 3  14  B001GVISJM  A18ECVX2RJ7HUE                  willie "roadie"
# 4  17  B001GVISJM  A3KLWF6WQ5BNYO                   Erica Neathery
# 5  28  B001GVISJM   AAAS38B98HMIK                     Heather Dube
# 6  33  B001EO5QW8   AOVROBZ8BNTP7                        S. Potter
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      4  1219017600
# 1                     3                       3      2  1307923200
# 2                     0                       0      4  1342051200
# 3                     2                       2      4  1288915200
# 4                     0                       0      2  1348099200
# 5                     0                       1      4  1331856000
# 6                    19                      19      4  1163376000
#
#                         Summary  \
# 0         "Delight" says it all
# 1                Cough Medicine
# 2                    Nice Taffy
# 3             fresh and greasy!
# 4                    poor taste
# 5   Great Bargain for the Price
# 6  Best of the Instant Oatmeals
#
#                                                 Text
# 0  This is a confection that has been around a fe...
# 1  If you are looking for the secret ingredient i...
# 2  I got a wild hair for taffy and ordered this f...
# 3  good flavor! these came securely packed... the...
# 4  I love eating them and they are good for watch...
# 5  I was so glad Amazon carried these batteries. ...
# 6  McCann's Instant Oatmeal is great if you must ...
